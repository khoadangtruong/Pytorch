# %% [markdown]
# <a href="https://colab.research.google.com/github/khoadangtruong/Pytorch/blob/master/Inception_Module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import glob
import pathlib
import torch
import numpy as np
import pandas as pd
from io import open
from PIL import Image
from torch import nn, optim, from_numpy, flatten
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, datasets

# %%
print(torch.__version__, torch.cuda.is_available())
# Out:
# 1.9.0+cu102 True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/scene.zip' -d '/content/data'

# %%
train_path = '/content/data/scene/seg_train/seg_train'
test_path = '/content/data/scene/seg_test/seg_test'
pred_path = '/content/data/scene/seg_pred/seg_pred'

# %%
root = pathlib.Path(train_path)
classes = sorted([j.name.split('/')[-1] for j in root.iterdir()])

# %%
print(classes, len(classes))
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street'] 6

# %%
transformers = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(
        [0.5, 0.5, 0.5],
        [0.5, 0.5, 0.5]
    )
])

# %%
train_loader = DataLoader(
    dataset = datasets.ImageFolder(root = train_path, transform = transformers),
    batch_size = 128,
    shuffle = True
)

test_loader = DataLoader(
    dataset = datasets.ImageFolder(root = test_path, transform = transformers),
    batch_size = 128,
    shuffle = True
)

# %%
import torch.nn.functional as F

# %%
class InceptionA(nn.Module):

    def __init__(self, in_channels):
        super(InceptionA, self).__init__()

        self.branch1x1 = nn.Conv2d(
            in_channels = in_channels, out_channels = 16, 
            kernel_size = 1, stride = 1, padding = 1
        )

        self.branch5x5_1 = nn.Conv2d(
            in_channels = in_channels, out_channels = 16,
            kernel_size = 1, stride = 1, padding = 1
        )
        self.branch5x5_2 = nn.Conv2d(
            in_channels = 16, out_channels = 24,
            kernel_size = 5, stride = 1, padding = 2
        )

        self.branch3x3_1 = nn.Conv2d(
            in_channels = in_channels, out_channels = 16,
            kernel_size = 1, stride = 1, padding = 1
        )
        self.branch3x3_2 = nn.Conv2d(
            in_channels = 16, out_channels = 24,
            kernel_size = 3, stride = 1, padding = 1
        )
        self.branch3x3_3 = nn.Conv2d(
            in_channels = 24, out_channels = 32,
            kernel_size = 3, stride = 1, padding = 1
        )

        self.branch_pool = nn.Conv2d(
            in_channels = in_channels, out_channels = 24,
            kernel_size = 1, stride = 1, padding = 1
        )
    
    def forward(self, x):
        
        branch1x1 = self.branch1x1(x)

        branch5x5_1 = self.branch5x5_1(x)
        branch5x5_2 = self.branch5x5_2(branch5x5_1)

        branch3x3_1 = self.branch3x3_1(x)
        branch3x3_2 = self.branch3x3_2(branch3x3_1)
        branch3x3_3 = self.branch3x3_3(branch3x3_2)

        avg_pool = F.avg_pool2d(input = x, kernel_size = 3, stride = 1, padding = 1)
        branch_pool = self.branch_pool(avg_pool)

        outputs = [branch1x1, branch5x5_2, branch3x3_3, branch_pool]
        return torch.cat(outputs, 1)

# %%
device = ('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Model(nn.Module):
    
    def __init__(self):
        super(Model, self).__init__()

        self.conv1 = nn.Conv2d(
            in_channels = 3, out_channels = 16,
            kernel_size = 5, stride = 1, padding = 1
        )
        self.bn1 = nn.BatchNorm2d(num_features = 16, momentum = 0.5)

        self.conv2 = nn.Conv2d(
            in_channels = 96, out_channels = 24,
            kernel_size = 5, stride = 1, padding = 1
        )
        self.bn2 = nn.BatchNorm2d(num_features = 24, momentum = 0.5)

        self.conv3 = nn.Conv2d(
            in_channels = 96, out_channels = 32,
            kernel_size = 5, stride = 1, padding = 1
        )
        self.bn3 = nn.BatchNorm2d(num_features = 32, momentum = 0.5)

        self.inception1 = InceptionA(16)
        self.inception2 = InceptionA(24)
        self.inception3 = InceptionA(32)

        self.max_pool = nn.MaxPool2d(
            kernel_size = 2, stride = 2 
        )

        self.fc1 = nn.Linear(38400, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 32)
        self.fc5 = nn.Linear(32, 6)

        self.relu = nn.ReLU()

    def forward(self, x):

        x = self.relu(self.max_pool(self.bn1(self.conv1(x))))
        x = self.inception1(x)
        x = self.relu(self.max_pool(self.bn2(self.conv2(x))))
        x = self.inception2(x)
        x = self.relu(self.max_pool(self.bn3(self.conv3(x))))
        x = self.inception3(x)
        
        x = flatten(x, 1)

        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        x = self.relu(self.fc4(x))
        x = self.fc5(x)

        return x

# %%
model = Model().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(params = model.parameters(), lr = 1e-3, weight_decay = 1e-4)

# %%
def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        if torch.cuda.is_available():
            data, target = Variable(data.cuda()), Variable(target.cuda())
        optimizer.zero_grad()
        outputs = model(data)
        loss = criterion(outputs, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print(f'Epoch: {epoch + 1} | Batch: {batch_idx * len(data)}/{len(train_loader.dataset)} | Loss: {loss.item():.4f}')

# %%
def test():
    model.eval()
    l_sum = 0
    correct = 0
    best_accuracy = 0.0
    with torch.no_grad():
        for data, target in test_loader:
            if torch.cuda.is_available():
                data, target = Variable(data.cuda()), Variable(target.cuda())
            outputs = model(data)
            loss = criterion(outputs, target)
            l_sum += loss.item()
            pred = outputs.data.max(1, keepdim = True)[1]
            correct += pred.eq(target.data.view_as(pred)).cpu().sum()
    
    avg_loss = l_sum / len(test_loader.dataset)
    test_accuracy = 100. * (correct / len(test_loader.dataset))
    print(f'Average loss: {avg_loss:.4f} | Accuracy: {test_accuracy:.0f}%')

    if test_accuracy > best_accuracy:
        torch.save(model.state_dict(), '/content/checkpoint.model')
        best_accuracy = test_accuracy

# %%
for epoch in range(20):
    train(epoch)
    test()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch: 1 | Batch: 0/14034 | Loss: 1.7808
# Epoch: 1 | Batch: 1280/14034 | Loss: 1.3918
# Epoch: 1 | Batch: 2560/14034 | Loss: 1.0904
# Epoch: 1 | Batch: 3840/14034 | Loss: 1.0234
# Epoch: 1 | Batch: 5120/14034 | Loss: 0.8462
# Epoch: 1 | Batch: 6400/14034 | Loss: 0.8332
# Epoch: 1 | Batch: 7680/14034 | Loss: 0.7678
# Epoch: 1 | Batch: 8960/14034 | Loss: 0.7223
# Epoch: 1 | Batch: 10240/14034 | Loss: 0.6542
# Epoch: 1 | Batch: 11520/14034 | Loss: 0.6625
# Epoch: 1 | Batch: 12800/14034 | Loss: 0.8422
# Average loss: 0.0057 | Accuracy: 73%
# Epoch: 2 | Batch: 0/14034 | Loss: 0.5832
# Epoch: 2 | Batch: 1280/14034 | Loss: 0.8443
# Epoch: 2 | Batch: 2560/14034 | Loss: 0.7352
# Epoch: 2 | Batch: 3840/14034 | Loss: 0.6953
# Epoch: 2 | Batch: 5120/14034 | Loss: 0.7467
# Epoch: 2 | Batch: 6400/14034 | Loss: 0.5684
# Epoch: 2 | Batch: 7680/14034 | Loss: 0.6558
# Epoch: 2 | Batch: 8960/14034 | Loss: 0.5191
# Epoch: 2 | Batch: 10240/14034 | Loss: 0.7007
# Epoch: 18 | Batch: 11520/14034 | Loss: 0.2509
# Epoch: 18 | Batch: 12800/14034 | Loss: 0.3353
# Average loss: 0.0039 | Accuracy: 86%
# Epoch: 19 | Batch: 0/14034 | Loss: 0.1704
# Epoch: 19 | Batch: 1280/14034 | Loss: 0.1714
# Epoch: 19 | Batch: 2560/14034 | Loss: 0.0981
# Epoch: 19 | Batch: 3840/14034 | Loss: 0.1304
# Epoch: 19 | Batch: 5120/14034 | Loss: 0.1302
# Epoch: 19 | Batch: 6400/14034 | Loss: 0.2324
# Epoch: 19 | Batch: 7680/14034 | Loss: 0.1823
# Epoch: 19 | Batch: 8960/14034 | Loss: 0.3098
# Epoch: 19 | Batch: 10240/14034 | Loss: 0.1841
# Epoch: 19 | Batch: 11520/14034 | Loss: 0.1921
# Epoch: 19 | Batch: 12800/14034 | Loss: 0.1778
# Average loss: 0.0039 | Accuracy: 85%
# Epoch: 20 | Batch: 0/14034 | Loss: 0.1016
# Epoch: 20 | Batch: 1280/14034 | Loss: 0.1194
# Epoch: 20 | Batch: 2560/14034 | Loss: 0.0905
# Epoch: 20 | Batch: 3840/14034 | Loss: 0.1820
# Epoch: 20 | Batch: 5120/14034 | Loss: 0.1762
# Epoch: 20 | Batch: 6400/14034 | Loss: 0.1260
# Epoch: 20 | Batch: 7680/14034 | Loss: 0.0993
# Epoch: 20 | Batch: 8960/14034 | Loss: 0.1206
# Epoch: 20 | Batch: 10240/14034 | Loss: 0.1550
# Epoch: 20 | Batch: 11520/14034 | Loss: 0.1629
# Epoch: 20 | Batch: 12800/14034 | Loss: 0.1343
# Average loss: 0.0043 | Accuracy: 83%

# %%
checkpoint = torch.load('/content/checkpoint.model')
model = Model()
model.load_state_dict(checkpoint)
model.eval()
# Out:
# Model(
#   (conv1): Conv2d(3, 16, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.5, affine=True, track_running_stats=True)
#   (conv2): Conv2d(96, 24, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.5, affine=True, track_running_stats=True)
#   (conv3): Conv2d(96, 32, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.5, affine=True, track_running_stats=True)
#   (inception1): InceptionA(
#     (branch1x1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (branch5x5_1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (branch5x5_2): Conv2d(16, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (branch3x3_1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (branch3x3_2): Conv2d(16, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (branch3x3_3): Conv2d(24, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (branch_pool): Conv2d(16, 24, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#   )
#   (inception2): InceptionA(
#     (branch1x1): Conv2d(24, 16, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (branch5x5_1): Conv2d(24, 16, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (branch5x5_2): Conv2d(16, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (branch3x3_1): Conv2d(24, 16, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (branch3x3_2): Conv2d(16, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (branch3x3_3): Conv2d(24, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (branch_pool): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#   )
#   (inception3): InceptionA(
#     (branch1x1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (branch5x5_1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (branch5x5_2): Conv2d(16, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (branch3x3_1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (branch3x3_2): Conv2d(16, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (branch3x3_3): Conv2d(24, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (branch_pool): Conv2d(32, 24, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#   )
#   (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=38400, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=64, bias=True)
#   (fc4): Linear(in_features=64, out_features=32, bias=True)
#   (fc5): Linear(in_features=32, out_features=6, bias=True)
#   (relu): ReLU()
# )

# %%
def prediction(img_path,transformer):

    image=Image.open(img_path)
    image_tensor = transformer(image).float()
    image_tensor = image_tensor.unsqueeze_(0)
    
    if torch.cuda.is_available():
        image_tensor.cuda()
        
    input=Variable(image_tensor)
    
    
    output=model(input)
    index=output.data.numpy().argmax()
    pred=classes[index]
    
    return pred

# %%
images_path = glob.glob(pred_path + '/*.jpg')

# %%
pred_dict = {}
for i in images_path:
    pred_dict[i[i.rfind('/')+1:]] = prediction(i,transformers)

# %%
pred_dict
# Out:
# {'11361.jpg': 'glacier',
#  '23134.jpg': 'glacier',
#  '5493.jpg': 'mountain',
#  '20193.jpg': 'buildings',
#  '11589.jpg': 'forest',
#  '20097.jpg': 'mountain',
#  '9326.jpg': 'mountain',
#  '1307.jpg': 'sea',
#  '19442.jpg': 'forest',
#  '22751.jpg': 'street',
#  '2055.jpg': 'glacier',
#  '3258.jpg': 'sea',
#  '22697.jpg': 'mountain',
#  '212.jpg': 'street',
#  '6806.jpg': 'mountain',
#  '17599.jpg': 'glacier',
#  '20526.jpg': 'mountain',
#  '18069.jpg': 'buildings',
#  '12587.jpg': 'buildings',
#  '13414.jpg': 'forest',
#  '18404.jpg': 'buildings',
#  '6727.jpg': 'mountain',
#  '14137.jpg': 'street',
#  '14855.jpg': 'glacier',
#  '7883.jpg': 'glacier',
#  '8174.jpg': 'sea',
#  '10914.jpg': 'buildings',
#  '17357.jpg': 'mountain',
#  '4525.jpg': 'glacier',
#  '198.jpg': 'mountain',
#  '10054.jpg': 'glacier',
#  '22052.jpg': 'forest',
#  '11463.jpg': 'sea',
#  '23341.jpg': 'mountain',
#  '4272.jpg': 'street',
#  '19788.jpg': 'glacier',
#  '2938.jpg': 'glacier',
#  '12271.jpg': 'buildings',
#  '22714.jpg': 'forest',
#  '7957.jpg': 'buildings',
#  '18836.jpg': 'forest',
#  '2825.jpg': 'glacier',
#  '8753.jpg': 'buildings',
#  '21914.jpg': 'buildings',
#  '16818.jpg': 'glacier',
#  '4245.jpg': 'glacier',
#  '11756.jpg': 'buildings',
#  '4502.jpg': 'street',
#  '13296.jpg': 'glacier',
#  '19482.jpg': 'forest',
#  '21109.jpg': 'glacier',
#  '4494.jpg': 'buildings',
#  '2632.jpg': 'forest',
#  '21190.jpg': 'forest',
#  '22979.jpg': 'buildings',
#  '485.jpg': 'sea',
#  '23021.jpg': 'mountain',
#  '11998.jpg': 'sea',
#  '4014.jpg': 'buildings',
#  '8403.jpg': 'forest',
#  '14688.jpg': 'glacier',
#  '23622.jpg': 'forest',
#  '3739.jpg': 'buildings',
#  '5567.jpg': 'buildings',
#  '736.jpg': 'buildings',
#  '10913.jpg': 'buildings',
#  '16497.jpg': 'forest',
#  '16841.jpg': 'mountain',
#  '9538.jpg': 'sea',
#  '13989.jpg': 'street',
#  '10669.jpg': 'street',
#  '9594.jpg': 'mountain',
#  '14737.jpg': 'forest',
#  '16058.jpg': 'forest',
#  '22984.jpg': 'forest',
#  '3421.jpg': 'sea',
#  '237.jpg': 'mountain',
#  '11752.jpg': 'forest',
#  '5981.jpg': 'buildings',
#  '4991.jpg': 'forest',
#  '12577.jpg': 'glacier',
#  '19201.jpg': 'forest',
#  '13342.jpg': 'buildings',
#  '23506.jpg': 'glacier',
#  '4881.jpg': 'forest',
#  '12841.jpg': 'buildings',
#  '2217.jpg': 'street',
#  '21758.jpg': 'glacier',
#  '12363.jpg': 'mountain',
#  '20456.jpg': 'mountain',
#  '21713.jpg': 'mountain',
#  '12095.jpg': 'glacier',
#  '20244.jpg': 'mountain',
#  '23916.jpg': 'buildings',
#  '568.jpg': 'sea',
#  '15170.jpg': 'buildings',
#  '6351.jpg': 'mountain',
#  '9711.jpg': 'mountain',
#  '17082.jpg': 'buildings',
#  '4443.jpg': 'mountain',
#  '1627.jpg': 'buildings',
#  '22178.jpg': 'mountain',
#  '17538.jpg': 'glacier',
#  '4153.jpg': 'street',
#  '9098.jpg': 'buildings',
#  '16023.jpg': 'sea',
#  '7190.jpg': 'sea',
#  '1239.jpg': 'mountain',
#  '13303.jpg': 'mountain',
#  '7106.jpg': 'street',
#  '18994.jpg': 'glacier',
#  '9882.jpg': 'buildings',
#  '17157.jpg': 'mountain',
#  '20503.jpg': 'mountain',
#  '203.jpg': 'buildings',
#  '6862.jpg': 'sea',
#  '10302.jpg': 'mountain',
#  '8917.jpg': 'street',
#  '24298.jpg': 'street',
#  '11065.jpg': 'glacier',
#  '22874.jpg': 'buildings',
#  '17850.jpg': 'sea',
#  '19059.jpg': 'buildings',
#  '12335.jpg': 'forest',
#  '5555.jpg': 'buildings',
#  '14981.jpg': 'mountain',
#  '2611.jpg': 'street',
#  '3508.jpg': 'glacier',
#  '16411.jpg': 'forest',
#  '13330.jpg': 'sea',
#  '2844.jpg': 'forest',
#  '17709.jpg': 'street',
#  '21010.jpg': 'sea',
#  '19751.jpg': 'buildings',
#  '1449.jpg': 'buildings',
#  '14976.jpg': 'forest',
#  '15712.jpg': 'buildings',
#  '9887.jpg': 'mountain',
#  '8865.jpg': 'mountain',
#  '22225.jpg': 'forest',
#  '17035.jpg': 'mountain',
#  '10166.jpg': 'mountain',
#  '11411.jpg': 'street',
#  '17167.jpg': 'buildings',
#  '4545.jpg': 'sea',
#  '21438.jpg': 'forest',
#  '14606.jpg': 'buildings',
#  '17908.jpg': 'forest',
#  '20760.jpg': 'forest',
#  '6017.jpg': 'glacier',
#  '5020.jpg': 'mountain',
#  '17128.jpg': 'sea',
#  '8667.jpg': 'street',
#  '18510.jpg': 'buildings',
#  '22674.jpg': 'forest',
#  '7905.jpg': 'mountain',
#  '1046.jpg': 'sea',
#  '20979.jpg': 'sea',
#  '11005.jpg': 'buildings',
#  '2766.jpg': 'sea',
#  '13413.jpg': 'mountain',
#  '23755.jpg': 'buildings',
#  '23621.jpg': 'mountain',
#  '18019.jpg': 'forest',
#  '9302.jpg': 'sea',
#  '12700.jpg': 'mountain',
#  '9500.jpg': 'forest',
#  '20445.jpg': 'mountain',
#  '22931.jpg': 'sea',
#  '17090.jpg': 'forest',
#  '10284.jpg': 'forest',
#  '18850.jpg': 'glacier',
#  '5844.jpg': 'glacier',
#  '9486.jpg': 'sea',
#  '16662.jpg': 'sea',
#  '11208.jpg': 'forest',
#  '4296.jpg': 'street',
#  '18395.jpg': 'mountain',
#  '16169.jpg': 'buildings',
#  '20025.jpg': 'glacier',
#  '23434.jpg': 'sea',
#  '18491.jpg': 'glacier',
#  '21441.jpg': 'mountain',
#  '23438.jpg': 'sea',
#  '1652.jpg': 'sea',
#  '1777.jpg': 'buildings',
#  '2106.jpg': 'glacier',
#  '9371.jpg': 'buildings',
#  '15646.jpg': 'buildings',
#  '10169.jpg': 'street',
#  '10241.jpg': 'forest',
#  '7976.jpg': 'buildings',
#  '15928.jpg': 'mountain',
#  '2330.jpg': 'forest',
#  '10844.jpg': 'forest',
#  '1596.jpg': 'buildings',
#  '9361.jpg': 'street',
#  '18948.jpg': 'street',
#  '11121.jpg': 'mountain',
#  '5693.jpg': 'street',
#  '12765.jpg': 'buildings',
#  '6427.jpg': 'glacier',
#  '4592.jpg': 'forest',
#  '12514.jpg': 'forest',
#  '7115.jpg': 'sea',
#  '7770.jpg': 'street',
#  '8583.jpg': 'mountain',
#  '8127.jpg': 'sea',
#  '10124.jpg': 'mountain',
#  '15629.jpg': 'forest',
#  '13585.jpg': 'sea',
#  '13297.jpg': 'sea',
#  '12199.jpg': 'mountain',
#  '21267.jpg': 'forest',
#  '4454.jpg': 'forest',
#  '18581.jpg': 'glacier',
#  '2039.jpg': 'buildings',
#  '12683.jpg': 'buildings',
#  '2739.jpg': 'mountain',
#  '5259.jpg': 'forest',
#  '13878.jpg': 'street',
#  '15353.jpg': 'mountain',
#  '13744.jpg': 'street',
#  '13727.jpg': 'mountain',
#  '11776.jpg': 'buildings',
#  '13840.jpg': 'buildings',
#  '10090.jpg': 'buildings',
#  '8083.jpg': 'sea',
#  '17813.jpg': 'glacier',
#  '20645.jpg': 'glacier',
#  '23412.jpg': 'mountain',
#  '7740.jpg': 'mountain',
#  '19577.jpg': 'forest',
#  '8361.jpg': 'forest',
#  '14395.jpg': 'glacier',
#  '14069.jpg': 'buildings',
#  '10082.jpg': 'street',
#  '9024.jpg': 'forest',
#  '21585.jpg': 'forest',
#  '9917.jpg': 'street',
#  '6122.jpg': 'forest',
#  '19473.jpg': 'mountain',
#  '1783.jpg': 'street',
#  '22658.jpg': 'street',
#  '12731.jpg': 'forest',
#  '7194.jpg': 'buildings',
#  '17665.jpg': 'buildings',
#  '13120.jpg': 'glacier',
#  '7907.jpg': 'street',
#  '4350.jpg': 'sea',
#  '22607.jpg': 'glacier',
#  '754.jpg': 'forest',
#  '7434.jpg': 'buildings',
#  '23720.jpg': 'sea',
#  '423.jpg': 'sea',
#  '19074.jpg': 'buildings',
#  '15649.jpg': 'mountain',
#  '12476.jpg': 'mountain',
#  '22729.jpg': 'buildings',
#  '14921.jpg': 'mountain',
#  '6066.jpg': 'street',
#  '18450.jpg': 'forest',
#  '7352.jpg': 'forest',
#  '20547.jpg': 'forest',
#  '11948.jpg': 'mountain',
#  '14771.jpg': 'buildings',
#  '3716.jpg': 'buildings',
#  '8812.jpg': 'forest',
#  '15994.jpg': 'buildings',
#  '2270.jpg': 'mountain',
#  '7743.jpg': 'street',
#  '19604.jpg': 'glacier',
#  '14908.jpg': 'glacier',
#  '7489.jpg': 'glacier',
#  '7099.jpg': 'street',
#  '22033.jpg': 'street',
#  '14765.jpg': 'sea',
#  '3564.jpg': 'forest',
#  '17182.jpg': 'buildings',
#  '22454.jpg': 'mountain',
#  '22327.jpg': 'buildings',
#  '24134.jpg': 'glacier',
#  '15396.jpg': 'forest',
#  '4562.jpg': 'street',
#  '23701.jpg': 'glacier',
#  '15929.jpg': 'buildings',
#  '7682.jpg': 'mountain',
#  '21172.jpg': 'sea',
#  '7575.jpg': 'sea',
#  '23690.jpg': 'mountain',
#  '2682.jpg': 'forest',
#  '19685.jpg': 'buildings',
#  '16634.jpg': 'street',
#  '2901.jpg': 'mountain',
#  '15172.jpg': 'mountain',
#  '3996.jpg': 'mountain',
#  '16084.jpg': 'buildings',
#  '15766.jpg': 'sea',
#  '23568.jpg': 'glacier',
#  '1914.jpg': 'buildings',
#  '20716.jpg': 'forest',
#  '548.jpg': 'buildings',
#  '8770.jpg': 'buildings',
#  '2130.jpg': 'forest',
#  '16484.jpg': 'street',
#  '5391.jpg': 'glacier',
#  '18641.jpg': 'sea',
#  '5706.jpg': 'mountain',
#  '23410.jpg': 'mountain',
#  '4424.jpg': 'street',
#  '24227.jpg': 'glacier',
#  '20012.jpg': 'glacier',
#  '10158.jpg': 'glacier',
#  '4355.jpg': 'sea',
#  '1568.jpg': 'sea',
#  '709.jpg': 'mountain',
#  '13102.jpg': 'buildings',
#  '4976.jpg': 'sea',
#  '4254.jpg': 'street',
#  '24191.jpg': 'glacier',
#  '19146.jpg': 'street',
#  '21439.jpg': 'sea',
#  '11693.jpg': 'mountain',
#  '9280.jpg': 'mountain',
#  '18879.jpg': 'buildings',
#  '12302.jpg': 'sea',
#  '16471.jpg': 'forest',
#  '18304.jpg': 'sea',
#  '13428.jpg': 'buildings',
#  '13237.jpg': 'buildings',
#  '15832.jpg': 'mountain',
#  '23396.jpg': 'glacier',
#  '15040.jpg': 'glacier',
#  '677.jpg': 'mountain',
#  '13963.jpg': 'mountain',
#  '19109.jpg': 'forest',
#  '251.jpg': 'mountain',
#  '7183.jpg': 'glacier',
#  '3703.jpg': 'buildings',
#  '6476.jpg': 'forest',
#  '23468.jpg': 'sea',
#  '8969.jpg': 'forest',
#  '17103.jpg': 'street',
#  '23631.jpg': 'glacier',
#  '14696.jpg': 'street',
#  '2689.jpg': 'glacier',
#  '6333.jpg': 'buildings',
#  '4061.jpg': 'glacier',
#  '9379.jpg': 'mountain',
#  '1724.jpg': 'street',
#  '6788.jpg': 'sea',
#  '10439.jpg': 'glacier',
#  '7368.jpg': 'mountain',
#  '6209.jpg': 'glacier',
#  '5197.jpg': 'mountain',
#  '5800.jpg': 'street',
#  '13768.jpg': 'sea',
#  '4712.jpg': 'sea',
#  '4369.jpg': 'street',
#  '6483.jpg': 'forest',
#  '17129.jpg': 'forest',
#  '1664.jpg': 'street',
#  '18695.jpg': 'glacier',
#  '19346.jpg': 'buildings',
#  '8873.jpg': 'street',
#  '9268.jpg': 'glacier',
#  '4702.jpg': 'forest',
#  '10469.jpg': 'sea',
#  '3515.jpg': 'mountain',
#  '10287.jpg': 'forest',
#  '17327.jpg': 'glacier',
#  '9225.jpg': 'mountain',
#  '622.jpg': 'mountain',
#  '7685.jpg': 'sea',
#  '5766.jpg': 'glacier',
#  '19500.jpg': 'buildings',
#  '22594.jpg': 'sea',
#  '2829.jpg': 'forest',
#  '1039.jpg': 'buildings',
#  '13162.jpg': 'mountain',
#  '19458.jpg': 'buildings',
#  '21705.jpg': 'sea',
#  '8282.jpg': 'mountain',
#  '3776.jpg': 'sea',
#  '21619.jpg': 'mountain',
#  '8160.jpg': 'mountain',
#  '12842.jpg': 'buildings',
#  '18274.jpg': 'mountain',
#  '600.jpg': 'mountain',
#  '17467.jpg': 'forest',
#  '672.jpg': 'forest',
#  '20340.jpg': 'forest',
#  '18246.jpg': 'glacier',
#  '24306.jpg': 'sea',
#  '11802.jpg': 'forest',
#  '21028.jpg': 'forest',
#  '18021.jpg': 'sea',
#  '3445.jpg': 'mountain',
#  '17316.jpg': 'glacier',
#  '7605.jpg': 'street',
#  '21815.jpg': 'buildings',
#  '19432.jpg': 'buildings',
#  '11674.jpg': 'buildings',
#  '20654.jpg': 'mountain',
#  '17459.jpg': 'buildings',
#  '6785.jpg': 'glacier',
#  '2251.jpg': 'glacier',
#  '8704.jpg': 'street',
#  '24064.jpg': 'forest',
#  '8804.jpg': 'street',
#  '16941.jpg': 'mountain',
#  '15612.jpg': 'buildings',
#  '20302.jpg': 'mountain',
#  '14520.jpg': 'glacier',
#  '8677.jpg': 'sea',
#  '6488.jpg': 'glacier',
#  '2700.jpg': 'mountain',
#  '7808.jpg': 'sea',
#  '2060.jpg': 'forest',
#  '20146.jpg': 'buildings',
#  '3472.jpg': 'glacier',
#  '12977.jpg': 'mountain',
#  '1130.jpg': 'mountain',
#  '718.jpg': 'sea',
#  '18904.jpg': 'street',
#  '4168.jpg': 'street',
#  '951.jpg': 'mountain',
#  '12920.jpg': 'forest',
#  '11250.jpg': 'buildings',
#  '10634.jpg': 'glacier',
#  '2026.jpg': 'sea',
#  '761.jpg': 'glacier',
#  '4237.jpg': 'street',
#  '2117.jpg': 'forest',
#  '7177.jpg': 'mountain',
#  '14112.jpg': 'mountain',
#  '8221.jpg': 'buildings',
#  '19065.jpg': 'mountain',
#  '7844.jpg': 'glacier',
#  '22287.jpg': 'mountain',
#  '8432.jpg': 'mountain',
#  '3770.jpg': 'sea',
#  '7394.jpg': 'mountain',
#  '8133.jpg': 'forest',
#  '1494.jpg': 'mountain',
#  '18134.jpg': 'buildings',
#  '18762.jpg': 'mountain',
#  '4734.jpg': 'street',
#  '1478.jpg': 'sea',
#  '930.jpg': 'glacier',
#  '1561.jpg': 'street',
#  '18370.jpg': 'forest',
#  '18459.jpg': 'sea',
#  '14450.jpg': 'mountain',
#  '13987.jpg': 'buildings',
#  '12291.jpg': 'street',
#  '9845.jpg': 'street',
#  '21969.jpg': 'forest',
#  '274.jpg': 'sea',
#  '22825.jpg': 'buildings',
#  '8011.jpg': 'forest',
#  '13042.jpg': 'mountain',
#  '23904.jpg': 'street',
#  '19219.jpg': 'forest',
#  '9996.jpg': 'street',
#  '7739.jpg': 'mountain',
#  '3065.jpg': 'street',
#  '23662.jpg': 'glacier',
#  '14267.jpg': 'mountain',
#  '22649.jpg': 'street',
#  '14813.jpg': 'forest',
#  '3027.jpg': 'buildings',
#  '16265.jpg': 'street',
#  '18254.jpg': 'street',
#  '11449.jpg': 'buildings',
#  '5303.jpg': 'glacier',
#  '21193.jpg': 'glacier',
#  '24182.jpg': 'buildings',
#  '7094.jpg': 'sea',
#  '24253.jpg': 'street',
#  '16608.jpg': 'mountain',
#  '9870.jpg': 'glacier',
#  '8417.jpg': 'mountain',
#  '15010.jpg': 'street',
#  '10005.jpg': 'mountain',
#  '23391.jpg': 'forest',
#  '16045.jpg': 'mountain',
#  '862.jpg': 'buildings',
#  '20453.jpg': 'glacier',
#  '2364.jpg': 'street',
#  '19006.jpg': 'forest',
#  '9461.jpg': 'mountain',
#  '9854.jpg': 'forest',
#  '7568.jpg': 'street',
#  '2248.jpg': 'glacier',
#  '320.jpg': 'street',
#  '19569.jpg': 'mountain',
#  '20977.jpg': 'street',
#  '23307.jpg': 'glacier',
#  '21561.jpg': 'forest',
#  '4960.jpg': 'buildings',
#  '13853.jpg': 'buildings',
#  '23251.jpg': 'glacier',
#  '11968.jpg': 'street',
#  '23335.jpg': 'forest',
#  '12371.jpg': 'street',
#  '15441.jpg': 'buildings',
#  '4105.jpg': 'mountain',
#  '8272.jpg': 'street',
#  '21791.jpg': 'sea',
#  '21549.jpg': 'forest',
#  '12006.jpg': 'sea',
#  '21778.jpg': 'forest',
#  '2595.jpg': 'mountain',
#  '11115.jpg': 'mountain',
#  '18734.jpg': 'forest',
#  '8251.jpg': 'forest',
#  '23834.jpg': 'street',
#  '2828.jpg': 'mountain',
#  '3223.jpg': 'buildings',
#  '8833.jpg': 'forest',
#  '18169.jpg': 'sea',
#  '17955.jpg': 'mountain',
#  '11901.jpg': 'buildings',
#  '14757.jpg': 'glacier',
#  '3672.jpg': 'glacier',
#  '1727.jpg': 'buildings',
#  '19899.jpg': 'street',
#  '6093.jpg': 'mountain',
#  '15266.jpg': 'sea',
#  '6461.jpg': 'buildings',
#  '799.jpg': 'forest',
#  '467.jpg': 'street',
#  '23960.jpg': 'mountain',
#  '23670.jpg': 'forest',
#  '7299.jpg': 'forest',
#  '19710.jpg': 'sea',
#  '17710.jpg': 'mountain',
#  '12936.jpg': 'street',
#  '14421.jpg': 'sea',
#  '785.jpg': 'glacier',
#  '9272.jpg': 'buildings',
#  '18956.jpg': 'buildings',
#  '4353.jpg': 'mountain',
#  '1897.jpg': 'mountain',
#  '16161.jpg': 'buildings',
#  '19648.jpg': 'forest',
#  '126.jpg': 'buildings',
#  '23063.jpg': 'forest',
#  '434.jpg': 'sea',
#  '23064.jpg': 'glacier',
#  '7444.jpg': 'sea',
#  '24102.jpg': 'forest',
#  '3393.jpg': 'buildings',
#  '1180.jpg': 'forest',
#  '152.jpg': 'forest',
#  '16408.jpg': 'glacier',
#  '8983.jpg': 'buildings',
#  '3127.jpg': 'mountain',
#  '14493.jpg': 'glacier',
#  '4274.jpg': 'forest',
#  '6179.jpg': 'street',
#  '7034.jpg': 'buildings',
#  '16140.jpg': 'forest',
#  '21474.jpg': 'forest',
#  '2861.jpg': 'sea',
#  '15924.jpg': 'sea',
#  '6121.jpg': 'sea',
#  '22282.jpg': 'mountain',
#  '12831.jpg': 'mountain',
#  '17738.jpg': 'street',
#  '20790.jpg': 'buildings',
#  '12293.jpg': 'street',
#  '8078.jpg': 'forest',
#  '15500.jpg': 'sea',
#  '18591.jpg': 'forest',
#  '12648.jpg': 'mountain',
#  '4286.jpg': 'street',
#  '9477.jpg': 'forest',
#  '1383.jpg': 'buildings',
#  '14739.jpg': 'mountain',
#  '11308.jpg': 'glacier',
#  '560.jpg': 'forest',
#  '4405.jpg': 'forest',
#  '4242.jpg': 'mountain',
#  '19033.jpg': 'sea',
#  '9205.jpg': 'glacier',
#  '18410.jpg': 'buildings',
#  '18766.jpg': 'forest',
#  '9382.jpg': 'buildings',
#  '5491.jpg': 'sea',
#  '15927.jpg': 'glacier',
#  '3578.jpg': 'forest',
#  '24331.jpg': 'forest',
#  '9828.jpg': 'glacier',
#  '5278.jpg': 'forest',
#  '14361.jpg': 'buildings',
#  '8945.jpg': 'buildings',
#  '22815.jpg': 'sea',
#  '5854.jpg': 'sea',
#  '13554.jpg': 'glacier',
#  '16737.jpg': 'forest',
#  '14522.jpg': 'street',
#  '23112.jpg': 'glacier',
#  '18543.jpg': 'glacier',
#  '9440.jpg': 'sea',
#  '10631.jpg': 'sea',
#  '4510.jpg': 'sea',
#  '6957.jpg': 'street',
#  '3026.jpg': 'street',
#  '4140.jpg': 'mountain',
#  '17988.jpg': 'buildings',
#  '2031.jpg': 'buildings',
#  '13335.jpg': 'mountain',
#  '7310.jpg': 'mountain',
#  '8851.jpg': 'glacier',
#  '9947.jpg': 'buildings',
#  '13302.jpg': 'forest',
#  '16449.jpg': 'buildings',
#  '5179.jpg': 'sea',
#  '19763.jpg': 'buildings',
#  '1082.jpg': 'buildings',
#  '6485.jpg': 'sea',
#  '5004.jpg': 'forest',
#  '10696.jpg': 'mountain',
#  '18338.jpg': 'forest',
#  '13161.jpg': 'glacier',
#  '16266.jpg': 'mountain',
#  '18083.jpg': 'sea',
#  '13095.jpg': 'sea',
#  '9110.jpg': 'street',
#  '645.jpg': 'buildings',
#  '23013.jpg': 'sea',
#  '4107.jpg': 'street',
#  '14162.jpg': 'sea',
#  '4687.jpg': 'buildings',
#  '15610.jpg': 'glacier',
#  '4591.jpg': 'buildings',
#  '8110.jpg': 'forest',
#  '1247.jpg': 'glacier',
#  '6738.jpg': 'glacier',
#  '16039.jpg': 'glacier',
#  '3838.jpg': 'glacier',
#  '24014.jpg': 'glacier',
#  '8320.jpg': 'mountain',
#  '18719.jpg': 'forest',
#  '7917.jpg': 'buildings',
#  '23704.jpg': 'glacier',
#  '5909.jpg': 'buildings',
#  '13513.jpg': 'forest',
#  '849.jpg': 'buildings',
#  '9864.jpg': 'sea',
#  '8568.jpg': 'buildings',
#  '10612.jpg': 'sea',
#  '15726.jpg': 'street',
#  '14508.jpg': 'mountain',
#  '19628.jpg': 'buildings',
#  '9122.jpg': 'sea',
#  '6163.jpg': 'buildings',
#  '23128.jpg': 'glacier',
#  '21566.jpg': 'glacier',
#  '11705.jpg': 'street',
#  '12137.jpg': 'mountain',
#  '18223.jpg': 'forest',
#  '6375.jpg': 'glacier',
#  '7405.jpg': 'sea',
#  '19155.jpg': 'sea',
#  '20529.jpg': 'mountain',
#  '16089.jpg': 'buildings',
#  '20377.jpg': 'glacier',
#  '6234.jpg': 'sea',
#  '1290.jpg': 'mountain',
#  '2246.jpg': 'mountain',
#  '23007.jpg': 'glacier',
#  '9710.jpg': 'mountain',
#  '13595.jpg': 'sea',
#  '18530.jpg': 'buildings',
#  '15305.jpg': 'buildings',
#  '10333.jpg': 'sea',
#  '21057.jpg': 'street',
#  '6446.jpg': 'buildings',
#  '18739.jpg': 'sea',
#  '5282.jpg': 'buildings',
#  '14886.jpg': 'sea',
#  '13865.jpg': 'forest',
#  '19467.jpg': 'street',
#  '21661.jpg': 'buildings',
#  '7385.jpg': 'mountain',
#  '11638.jpg': 'sea',
#  '23440.jpg': 'forest',
#  '20552.jpg': 'glacier',
#  '17084.jpg': 'street',
#  '15933.jpg': 'sea',
#  '16552.jpg': 'buildings',
#  '21654.jpg': 'mountain',
#  '20291.jpg': 'buildings',
#  '3789.jpg': 'sea',
#  '6459.jpg': 'buildings',
#  '9107.jpg': 'street',
#  '17870.jpg': 'glacier',
#  '21883.jpg': 'buildings',
#  '14169.jpg': 'buildings',
#  '2572.jpg': 'buildings',
#  '3283.jpg': 'sea',
#  '19686.jpg': 'forest',
#  '19457.jpg': 'street',
#  '4888.jpg': 'glacier',
#  '8946.jpg': 'sea',
#  '6822.jpg': 'buildings',
#  '2488.jpg': 'buildings',
#  '2046.jpg': 'mountain',
#  '21133.jpg': 'street',
#  '24259.jpg': 'mountain',
#  '9688.jpg': 'mountain',
#  '15706.jpg': 'buildings',
#  '2227.jpg': 'mountain',
#  '15737.jpg': 'mountain',
#  '19980.jpg': 'forest',
#  '8806.jpg': 'buildings',
#  '21830.jpg': 'mountain',
#  '21131.jpg': 'street',
#  '13345.jpg': 'forest',
#  '8979.jpg': 'glacier',
#  '8783.jpg': 'glacier',
#  '16436.jpg': 'buildings',
#  '2466.jpg': 'mountain',
#  '11328.jpg': 'mountain',
#  '8759.jpg': 'glacier',
#  '8215.jpg': 'buildings',
#  '23494.jpg': 'glacier',
#  '19082.jpg': 'buildings',
#  '20321.jpg': 'forest',
#  '13333.jpg': 'mountain',
#  '4328.jpg': 'street',
#  '20360.jpg': 'sea',
#  '22523.jpg': 'forest',
#  '12334.jpg': 'sea',
#  '2734.jpg': 'street',
#  '20850.jpg': 'mountain',
#  '17699.jpg': 'buildings',
#  '21822.jpg': 'buildings',
#  '13552.jpg': 'glacier',
#  '766.jpg': 'sea',
#  '22319.jpg': 'buildings',
#  '20814.jpg': 'forest',
#  '10269.jpg': 'mountain',
#  '23028.jpg': 'buildings',
#  '4636.jpg': 'glacier',
#  '4240.jpg': 'forest',
#  '18545.jpg': 'glacier',
#  '6027.jpg': 'street',
#  '19481.jpg': 'mountain',
#  '9121.jpg': 'sea',
#  '23983.jpg': 'mountain',
#  '20049.jpg': 'sea',
#  '7954.jpg': 'buildings',
#  '858.jpg': 'glacier',
#  '16777.jpg': 'forest',
#  '7104.jpg': 'buildings',
#  '7301.jpg': 'forest',
#  '14053.jpg': 'glacier',
#  '13817.jpg': 'forest',
#  '16405.jpg': 'mountain',
#  '7796.jpg': 'forest',
#  '4361.jpg': 'glacier',
#  '21698.jpg': 'glacier',
#  '2722.jpg': 'buildings',
#  '676.jpg': 'mountain',
#  '15381.jpg': 'sea',
#  '23017.jpg': 'mountain',
#  '513.jpg': 'buildings',
#  '3101.jpg': 'forest',
#  '4760.jpg': 'buildings',
#  '6811.jpg': 'glacier',
#  '5322.jpg': 'glacier',
#  '546.jpg': 'buildings',
#  '5942.jpg': 'buildings',
#  '6250.jpg': 'mountain',
#  '21930.jpg': 'forest',
#  '22621.jpg': 'glacier',
#  '15063.jpg': 'sea',
#  '3206.jpg': 'buildings',
#  '14829.jpg': 'sea',
#  '14977.jpg': 'forest',
#  '4713.jpg': 'buildings',
#  '12869.jpg': 'glacier',
#  '1797.jpg': 'buildings',
#  '2620.jpg': 'forest',
#  '19801.jpg': 'forest',
#  '16186.jpg': 'mountain',
#  '5732.jpg': 'forest',
#  '8068.jpg': 'buildings',
#  '3981.jpg': 'glacier',
#  '19994.jpg': 'mountain',
#  '3022.jpg': 'sea',
#  '13262.jpg': 'buildings',
#  '13085.jpg': 'sea',
#  '20797.jpg': 'street',
#  '19933.jpg': 'street',
#  '23415.jpg': 'street',
#  '11983.jpg': 'buildings',
#  '4526.jpg': 'mountain',
#  '18626.jpg': 'mountain',
#  '19424.jpg': 'glacier',
#  '19503.jpg': 'mountain',
#  '11546.jpg': 'mountain',
#  '8369.jpg': 'mountain',
#  '16864.jpg': 'glacier',
#  '12422.jpg': 'glacier',
#  '16106.jpg': 'mountain',
#  '15461.jpg': 'mountain',
#  '7583.jpg': 'sea',
#  '8135.jpg': 'buildings',
#  '12707.jpg': 'mountain',
#  '5067.jpg': 'sea',
#  '15178.jpg': 'street',
#  '17398.jpg': 'street',
#  '19393.jpg': 'mountain',
#  '10017.jpg': 'mountain',
#  '16689.jpg': 'sea',
#  '374.jpg': 'forest',
#  '2737.jpg': 'sea',
#  '14895.jpg': 'glacier',
#  '5227.jpg': 'forest',
#  '11017.jpg': 'sea',
#  '22838.jpg': 'forest',
#  '9154.jpg': 'glacier',
#  '4036.jpg': 'mountain',
#  '15638.jpg': 'glacier',
#  '20883.jpg': 'sea',
#  '8664.jpg': 'sea',
#  '487.jpg': 'sea',
#  '17513.jpg': 'sea',
#  '10366.jpg': 'sea',
#  '23693.jpg': 'forest',
#  '10918.jpg': 'buildings',
#  '21531.jpg': 'sea',
#  '19092.jpg': 'sea',
#  '10625.jpg': 'sea',
#  '2719.jpg': 'forest',
#  '2694.jpg': 'buildings',
#  '18172.jpg': 'buildings',
#  '7934.jpg': 'glacier',
#  '14424.jpg': 'sea',
#  '13867.jpg': 'sea',
#  '2271.jpg': 'sea',
#  '13299.jpg': 'glacier',
#  '17938.jpg': 'buildings',
#  '13704.jpg': 'mountain',
#  '608.jpg': 'buildings',
#  '13331.jpg': 'buildings',
#  '8426.jpg': 'forest',
#  '19088.jpg': 'sea',
#  '1241.jpg': 'sea',
#  '6297.jpg': 'sea',
#  '17658.jpg': 'mountain',
#  '11454.jpg': 'mountain',
#  '6574.jpg': 'sea',
#  '23278.jpg': 'street',
#  '6542.jpg': 'forest',
#  '8815.jpg': 'forest',
#  '9804.jpg': 'mountain',
#  '23216.jpg': 'mountain',
#  '1053.jpg': 'buildings',
#  '20551.jpg': 'glacier',
#  '21696.jpg': 'sea',
#  '9599.jpg': 'mountain',
#  '23914.jpg': 'forest',
#  '19181.jpg': 'buildings',
#  '2860.jpg': 'glacier',
#  '16825.jpg': 'forest',
#  '11757.jpg': 'glacier',
#  '9849.jpg': 'sea',
#  '24272.jpg': 'mountain',
#  '21166.jpg': 'buildings',
#  '12015.jpg': 'glacier',
#  '10171.jpg': 'glacier',
#  '16217.jpg': 'forest',
#  '13438.jpg': 'street',
#  '16840.jpg': 'buildings',
#  '632.jpg': 'mountain',
#  '15137.jpg': 'street',
#  '13799.jpg': 'sea',
#  '22039.jpg': 'buildings',
#  '3452.jpg': 'forest',
#  '7160.jpg': 'forest',
#  '12989.jpg': 'forest',
#  '17388.jpg': 'sea',
#  '22715.jpg': 'sea',
#  '5288.jpg': 'sea',
#  '10092.jpg': 'forest',
#  '12286.jpg': 'buildings',
#  '15902.jpg': 'mountain',
#  '4896.jpg': 'mountain',
#  '14821.jpg': 'buildings',
#  '11496.jpg': 'sea',
#  '2011.jpg': 'forest',
#  '22146.jpg': 'buildings',
#  '10522.jpg': 'forest',
#  '22498.jpg': 'mountain',
#  '19262.jpg': 'forest',
#  '23302.jpg': 'sea',
#  '12087.jpg': 'buildings',
#  '4503.jpg': 'buildings',
#  '17748.jpg': 'glacier',
#  '15631.jpg': 'street',
#  '23326.jpg': 'street',
#  '12628.jpg': 'mountain',
#  '12325.jpg': 'glacier',
#  '15686.jpg': 'glacier',
#  '21080.jpg': 'glacier',
#  '20499.jpg': 'sea',
#  '20509.jpg': 'sea',
#  '17163.jpg': 'glacier',
#  '6732.jpg': 'mountain',
#  '14276.jpg': 'mountain',
#  '22713.jpg': 'buildings',
#  '22582.jpg': 'glacier',
#  '21802.jpg': 'mountain',
#  '22174.jpg': 'buildings',
#  '3252.jpg': 'mountain',
#  '5957.jpg': 'sea',
#  '16603.jpg': 'glacier',
#  '3231.jpg': 'mountain',
#  '18859.jpg': 'glacier',
#  '2789.jpg': 'mountain',
#  '12537.jpg': 'sea',
#  '6807.jpg': 'glacier',
#  '19875.jpg': 'buildings',
#  '17342.jpg': 'glacier',
#  '12285.jpg': 'forest',
#  '6840.jpg': 'forest',
#  '20578.jpg': 'street',
#  '22333.jpg': 'street',
#  '18377.jpg': 'buildings',
#  '24121.jpg': 'forest',
#  '4262.jpg': 'buildings',
#  '2554.jpg': 'mountain',
#  '23460.jpg': 'glacier',
#  '23913.jpg': 'mountain',
#  '16304.jpg': 'glacier',
#  '4804.jpg': 'glacier',
#  '16351.jpg': 'forest',
#  '4703.jpg': 'forest',
#  '18054.jpg': 'sea',
#  '6794.jpg': 'street',
#  '6783.jpg': 'mountain',
#  '5066.jpg': 'glacier',
#  '6611.jpg': 'buildings',
#  '19797.jpg': 'mountain',
#  '15391.jpg': 'buildings',
#  '6882.jpg': 'mountain',
#  '12250.jpg': 'glacier',
#  '9027.jpg': 'sea',
#  '19767.jpg': 'buildings',
#  '23035.jpg': 'mountain',
#  '11120.jpg': 'sea',
#  '23358.jpg': 'street',
#  '19941.jpg': 'glacier',
#  '4222.jpg': 'buildings',
#  '9836.jpg': 'street',
#  '9264.jpg': 'forest',
#  '15004.jpg': 'street',
#  '14380.jpg': 'forest',
#  '10814.jpg': 'street',
#  '23863.jpg': 'mountain',
#  '12949.jpg': 'mountain',
#  '1388.jpg': 'sea',
#  '15912.jpg': 'mountain',
#  '4765.jpg': 'street',
#  '2198.jpg': 'street',
#  '23083.jpg': 'sea',
#  '11854.jpg': 'mountain',
#  '22532.jpg': 'street',
#  '21202.jpg': 'mountain',
#  '20827.jpg': 'forest',
#  '3832.jpg': 'buildings',
#  '22288.jpg': 'street',
#  '23523.jpg': 'forest',
#  '18627.jpg': 'glacier',
#  '23680.jpg': 'glacier',
#  '2686.jpg': 'forest',
#  '7762.jpg': 'forest',
#  '4925.jpg': 'buildings',
#  '15315.jpg': 'forest',
#  '13694.jpg': 'buildings',
#  '15208.jpg': 'buildings',
#  '7467.jpg': 'mountain',
#  '9713.jpg': 'sea',
#  '6872.jpg': 'mountain',
#  '5251.jpg': 'sea',
#  '13845.jpg': 'forest',
#  '12498.jpg': 'sea',
#  '11422.jpg': 'glacier',
#  '22529.jpg': 'buildings',
#  '4588.jpg': 'sea',
#  '13900.jpg': 'glacier',
#  '5528.jpg': 'sea',
#  '14155.jpg': 'glacier',
#  '13017.jpg': 'buildings',
#  ...}
